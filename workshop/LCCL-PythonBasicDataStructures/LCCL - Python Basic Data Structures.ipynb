# %% [markdown]
# # Welcome and Contents
# Welcome to the workshop. This workshop is intended for participants of the Shopee Code League 2021. Participant is assumed to have attended the Introductory Python workshop conducted by LCCL on 22 Feb.
#
# This file is to be used alongside the workshop slides. Participants will likely learn better if they code along during the workshop and take generous notes.
#
# Contents of this notebook:
#
# 1. String
# 2. List
# 3. Tuple
# 4. Set
# 5. Dictionary

# %% [markdown]
# # Segment 1

# %% [markdown]
# ## 1. String

# %% [markdown]
# We don't normally think of strings as a data structure. It is added to this Basic Data Structure workshop since it is a common data type.

# %%
# Accessing a string character
name = 'Princess Diana of Themyscira, Daughter of Hippolyta'
name[0]

# %%
# Slicing
name[9:14]

# %%
# Length
len(name)

# %%
# Concatenation
child = name[9:14]
mother = name[-9:]
print(child + " is " + mother + "'s daughter")

# %%
# Substring membership
'Hippo' in name
'hippo' in name

# %%
# String methods
help(str)

# %% [markdown]
# ## 2. List

# %%
# Creating a list
food = []        # empty list
drinks = list()  # empty list
fruits = ['banana', 'custard apple', 'peach', 'grapes']

# Python list can store any data values
fruits = ['banana', 5, 2.3, True]

three_cards = [
    ['9c', 'Jd', '3d'],
    ['8c', 'Th', 'Kd'],
    ['5h', '4d', '7h'],
    ['8s', '2d', 'Qh'],
    ['Ah', 'Ts', '9h'],
]

# %%
# Accessing list item
fruits[0]   # 'banana'
fruits[2]   # 'peach'
fruits[-1]  # 'grapes'
# fruits[4]   # IndexError: index out of range

# three_cards[2][0]    
# three_cards[4][1]

# %%
# Change list item
fruits[0] = 'apple' 
fruits
# bingo_card[4][4] = 1000
# bingo_card

# %%
# Length of a list
len(fruits)     # 4
len(bingo_card)
len(bingo_card[0])

# %%
# Slicing
fruits[1:3]     # ['custard apple', 'peach']

# %%
# Concatenation
cat_persons = ['Nancy', 'Josiah', 'Peter']
dog_persons = ['Angie', 'Julia', 'Desmond']

everyone = cat_persons + dog_persons
print(everyone)

# %%
# Membership
'peach' in fruits       # True
'durian' in fruits      # False

# %%
# List iteration
for fruit in fruits: 
    print(f'{fruit.capitalize()} is a fruit.')

# %%
# enumerate()
print('\nGROCERY LIST:')
for i, fruit in enumerate(fruits): 
    print(f'{i+1}. {fruit}')

# %% [markdown]
# ## Hands-On #1

# %% [markdown]
# A string is a palindrome if it is identical forward and backward.
#
# For example, “anna”, “civic”, “level” and “hannah” are all examples of palindromic words.
#
# Write a program that reads a string from the user and uses a loop to determine whether or not it is a palindrome. Display the result, including a meaningful output message.

# %% [markdown]
# ## Hands-On #2

# %% [markdown]
# Write a program that reads numbers from the user until a blank line is entered.
#
# Your program should display the average of all of the values entered by the user.
#
# Then the program should display all of the below average values, followed by all of the average values (if any), followed by all of the above average values.
#
# An appropriate label should be displayed before each list of values.

# %% [markdown]
# ## Hands-On #3

# %% [markdown]
# A deck of playing cards contains 52 cards. Each card has one of four suits along with a value. The suits are spades, hearts, diamonds and clubs while
# the values are 2 through 10, Jack, Queen, King and Ace.
#
# Each playing card can be represented using two characters. The first character is
# the value of the card, with the values 2 through 9 being represented directly. The characters “T”, “J”, “Q”, “K” and “A” are used to represent the values 10, Jack, Queen, King and Ace respectively.
#
# The second character is used to represent the suit of the card. It is normally a lowercase letter: “s” for spades, “h” for hearts, “d” for diamonds and “c” for clubs.
#
# Examples of cards and their two-character representations:
#
# * Jack of spades: Js
# * Two of clubs: 2c
# * Ten of diamonds: Td
# * Ace of hearts: Ah
# * Nine of spades: 9s
#
# Write a function named create_deck to create a complete deck of cards by storing the two-character abbreviations for all 52 cards into a list. Return the list of cards as the function’s only result. Your function will not take any parameters.

# %%
def create_deck():
    # enter code here
    return []

# %% [markdown]
# # Segment 2

# %% [markdown]
# ## 3. Tuple

# %% [markdown]
# An immutable sequence type.

# %%
# Creating a tuple
scores = tuple()
scores = ()
scores = (1,2,3,1,1) 
m = (7, 'Holland')

# %%
# Accessing a value
scores[2]    # 3

# %%
# Adding item
scores += (0,0,2,3,3)   # scores = scores + (0,0,2,3,3) 
scores += (1,)

# %%
# Membership
10 in scores    # False

# Iterating through a tuple
for s in scores:
    print(s)

# Length
len(scores)

# %% [markdown]
# ## 4. Set

# %%
# Creating a set
fruits = set()
my_fav_food = {'nasi lemak', 'laksa', 'hokkien mee', 'chicken rice'}
your_fav_food = {'chicken rice', 'pan mee', 'nasi lemak'}

# %%
# Adding item
fruits.add('durian')   # no duplicates

# %%
# Deleting a set item
fruits.discard('durian')

# %%
# Membership
'chicken rice' in your_fav_food  # True

# %%
# Iterating through a set
for food in my_fav_food:
    print(food)

# %%
# Set intersection
my_fav_food & your_fav_food     # {'nasi lemak', 'chicken rice'}

# %%
# Set union
my_fav_food | your_fav_food     # {'chicken rice', 'hokkien mee', 'laksa', 'nasi lemak', 'pan mee'}

# %%
# Set difference
my_fav_food - your_fav_food     # {'laksa', 'hokkien mee'}

# %%
# Length
len(my_fav_food)

# %% [markdown]
# ## 5. Dictionary

# %% [markdown]
# A collection of key-value pairs.

# %%
# Creating a dictionary
phonebook = dict()

d = {}

capitals = {
    'Singaore': 'Singapore', 
    'Malaysia': 'Kuala Lumpur', 
    'Philippines': 'Manila',
    'Thailand': 'Bangkok',
    'Indonesia': 'Jakarta',
    'Taiwan': 'Taipei',
}

d = {'a': 31, 24:'x', 1.23: [4,5,6]}

# %%
# Accessing a value
capitals['Malaysia']    # Kuala Lumpur
d['a']                  # 31
d[24]                   # x

# %%
# Adding/Updating key-value pair
capitals['Vietnam'] = 'Hanoi'

# %%
# Deleting a dictionary item
d.pop(1.23)

# %%
# Membership
'Thailand' in capitals  # True

# %%
# Iterating through a dictionary
for k, v in capitals.items():
    print(f'{v} is the capital of {k}.')

# %%
# Length
len(capitals)

# %% [markdown]
# ## Hands-On #4

# %% [markdown]
# Print the number of unique case-sensitive characters in a string.

# %% [markdown]
# ## Hands-On #5

# %% [markdown]
# Create a Pig Latin translator. Rules to convert English to Pig Latin:
#
# Words that start with a vowel will end with ‘ay’ e.g. ‘eggs’ → ‘eggsay’
#
# Words that start with a consonant will have its consonant group move to the end and appended with ‘ay’ e.g. ‘shop’ → ‘opshay’
#
# Treat ‘y’ as a vowel.

# %% [markdown]
# ## Hands-On #6

# %% [markdown]
# Take an input string and report groups of words that start with the same letter.

# %%
def report(s):
    # enter code here
    return {}

# test 
report('''
    Someday I'll wish upon a star 
    Wake up where the clouds are far behind me 
    Where trouble melts like lemon drops 
    High above the chimney top 
    That's where you'll find me
    '''
)

# %% [markdown]
# ## Hands-On #7

# %% [markdown]
# Create a function that behaves this way:
#
# ```
# foo(["run","jump","run","jump","run"],   "_|_|_")		# "_|_|_"
# foo(["run","jump","run","run","run"],    "_|_|_")		# "_|_/_"
# foo(["run","run","run","run","run"],     "_|_|_")		# "_/_/_"
# foo(["jump","jump","jump","jump","jump"],"_|_|_")		# "x|x|x"
# foo(["jump","run","jump","run","jump"],  "_|_|_")		# "x/x/x"
# ```

# %%
def foo(act, s):
    # enter code here
    return ''

# test
print(foo(['run', 'jump'], '|_'))
print(foo(["run","jump","run","jump","run"],   "_|_|_"))
print(foo(["run","jump","run","run","run"],    "_|_|_"))
print(foo(["run","run","run","run","run"],     "_|_|_"))
print(foo(["jump","jump","jump","jump","jump"],"_|_|_"))
print(foo(["jump","run","jump","run","jump"],  "_|_|_"))
